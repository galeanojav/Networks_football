# %% [markdown]
# # Dibujando los disparos en nuestro terreno de juego

# %%
#ID for Spain vs USA Womens World Cup
match_id_required = 69161
home_team_required ="Spain Women's"
away_team_required ="United States Women's"

# %%
file_name=str(match_id_required)+'.json'

# %%
#Load in all match events 
import json
with open('../Tema2/Statsbomb/data/events/'+file_name) as data_file:
    #print (mypath+'events/'+file)
    data = json.load(data_file)

# %%
data
# Out:
# [{'id': '413582c3-a655-4821-968f-6bdf53906d16',
#   'index': 1,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'duration': 0.0,
#   'tactics': {'formation': 433,
#    'lineup': [{'player': {'id': 10142, 'name': 'Sandra Paños García-Villamil'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 13},
#     {'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 7},
#     {'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 4},
#     {'player': {'id': 10155, 'name': 'María Pilar León Cebrián'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 16},
#     {'player': {'id': 10163, 'name': 'Leila Ouahabi El Ouahabi'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 3},
#     {'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'jersey_number': 14},
#     {'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'jersey_number': 6},
#     {'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'jersey_number': 12},
#     {'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'jersey_number': 17},
#     {'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'jersey_number': 11},
#     {'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 10}]}},
#  {'id': 'bd1acd1d-62c5-4f5b-b589-1414f88804cc',
#   'index': 2,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'duration': 0.0,
#   'tactics': {'formation': 433,
#    'lineup': [{'player': {'id': 5100, 'name': 'Alyssa Naeher'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 1},
#     {'player': {'id': 5021, 'name': 'Kelley O"Hara'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 5},
#     {'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 7},
#     {'player': {'id': 5030, 'name': 'Becky Sauerbrunn'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 4},
#     {'player': {'id': 5088, 'name': 'Crystal Alyssia Dunn'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 19},
#     {'player': {'id': 6811, 'name': 'Julie Ertz'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'jersey_number': 8},
#     {'player': {'id': 4949, 'name': 'Rose Lavelle'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'jersey_number': 16},
#     {'player': {'id': 5087, 'name': 'Samantha Mewis'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'jersey_number': 3},
#     {'player': {'id': 5013, 'name': 'Tobin Heath'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'jersey_number': 17},
#     {'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'jersey_number': 15},
#     {'player': {'id': 5085, 'name': 'Alex Morgan'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 13}]}},
#  {'id': '4205c4b8-d57f-47a7-9e42-6c148dafdb06',
#   'index': 3,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'duration': 0.0,
#   'related_events': ['6223be74-60bb-4248-b1d1-02ecf9ce337e']},
#  {'id': '6223be74-60bb-4248-b1d1-02ecf9ce337e',
#   'index': 4,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'duration': 0.0,
#   'related_events': ['4205c4b8-d57f-47a7-9e42-6c148dafdb06']},
#  {'id': '6c519b96-4646-47ca-adcf-2385bddd79da',
#   'index': 5,
#   'period': 1,
#   'timestamp': '00:00:00.689',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [60.0, 40.0],
#   'duration': 1.8506,
#   'related_events': ['41cc79f7-f05d-49f6-a9c9-47ad6c9e4f56'],
#   'pass': {'recipient': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#    'length': 24.71639,
#    'angle': 2.883857,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [36.1, 46.3],
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'type': {'id': 65, 'name': 'Kick Off'}}},
#  {'id': '41cc79f7-f05d-49f6-a9c9-47ad6c9e4f56',
#   'index': 6,
#   'period': 1,
#   'timestamp': '00:00:02.539',
#   'minute': 0,
#   'second': 2,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [36.1, 46.3],
#   'related_events': ['6c519b96-4646-47ca-adcf-2385bddd79da']},
#  {'id': 'cab87504-e629-45b6-9a59-c717ee180c8b',
#   'index': 7,
#   'period': 1,
#   'timestamp': '00:00:02.539',
#   'minute': 0,
#   'second': 2,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [36.1, 46.3],
#   'duration': 0.12,
#   'related_events': ['41cc79f7-f05d-49f6-a9c9-47ad6c9e4f56',
#    'ee3be773-1d8a-40b9-a4f5-de9e63a54301'],
#   'carry': {'end_location': [34.7, 46.7]}},
#  {'id': 'ee3be773-1d8a-40b9-a4f5-de9e63a54301',
#   'index': 8,
#   'period': 1,
#   'timestamp': '00:00:02.659',
#   'minute': 0,
#   'second': 2,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [34.7, 46.7],
#   'duration': 3.3197,
#   'related_events': ['17450343-aa4b-4295-b725-cae1fef50cce',
#    '8a3f616f-a373-4a75-88a7-8a4e28960ff1'],
#   'pass': {'recipient': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#    'length': 60.88021,
#    'angle': -0.5077367,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [87.9, 17.1],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '8a3f616f-a373-4a75-88a7-8a4e28960ff1',
#   'index': 9,
#   'period': 1,
#   'timestamp': '00:00:05.979',
#   'minute': 0,
#   'second': 5,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [81.6, 13.0],
#   'related_events': ['ee3be773-1d8a-40b9-a4f5-de9e63a54301'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '17450343-aa4b-4295-b725-cae1fef50cce',
#   'index': 10,
#   'period': 1,
#   'timestamp': '00:00:05.979',
#   'minute': 0,
#   'second': 5,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5021, 'name': 'Kelley O"Hara'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [33.1, 63.9],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['ee3be773-1d8a-40b9-a4f5-de9e63a54301'],
#   'clearance': {'head': True, 'body_part': {'id': 37, 'name': 'Head'}}},
#  {'id': 'b8be405b-ad05-4f6f-b6c8-a2e3b86b603d',
#   'index': 11,
#   'period': 1,
#   'timestamp': '00:00:07.765',
#   'minute': 0,
#   'second': 7,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [71.3, 25.6],
#   'duration': 0.0},
#  {'id': '0134c413-9fd3-415d-87c6-6d8d11992465',
#   'index': 12,
#   'period': 1,
#   'timestamp': '00:00:08.751',
#   'minute': 0,
#   'second': 8,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [73.9, 26.2],
#   'duration': 0.7026,
#   'related_events': ['308e5a70-f5f5-40f8-82a9-87e6d0c3612a'],
#   'pass': {'recipient': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#    'length': 5.770615,
#    'angle': 1.4141945,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [74.8, 31.9],
#    'body_part': {'id': 37, 'name': 'Head'},
#    'outcome': {'id': 77, 'name': 'Unknown'}}},
#  {'id': '308e5a70-f5f5-40f8-82a9-87e6d0c3612a',
#   'index': 13,
#   'period': 1,
#   'timestamp': '00:00:09.453',
#   'minute': 0,
#   'second': 9,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [74.6, 34.1],
#   'related_events': ['0134c413-9fd3-415d-87c6-6d8d11992465'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'bd661407-7047-45e7-a94e-9ec819fafc01',
#   'index': 14,
#   'period': 1,
#   'timestamp': '00:00:29.023',
#   'minute': 0,
#   'second': 29,
#   'type': {'id': 41, 'name': 'Referee Ball-Drop'},
#   'possession': 3,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 5, 'name': 'Other'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'location': [73.9, 32.8],
#   'duration': 0.0},
#  {'id': 'da05882d-ad2f-4f2d-aa95-016eb6cfe27e',
#   'index': 15,
#   'period': 1,
#   'timestamp': '00:00:29.048',
#   'minute': 0,
#   'second': 29,
#   'type': {'id': 41, 'name': 'Referee Ball-Drop'},
#   'possession': 4,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 5, 'name': 'Other'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'location': [47.1, 48.2],
#   'duration': 0.0},
#  {'id': '526da747-5500-47e1-a67a-742eb3bb3231',
#   'index': 16,
#   'period': 1,
#   'timestamp': '00:00:30.424',
#   'minute': 0,
#   'second': 30,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [69.8, 30.8],
#   'duration': 1.1561,
#   'related_events': ['a2ae2726-fb1e-4508-a12e-9619690f33fc'],
#   'pass': {'recipient': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#    'length': 13.535139,
#    'angle': -0.33109608,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [82.6, 26.4],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'type': {'id': 66, 'name': 'Recovery'}}},
#  {'id': '24d32d81-62fd-4c9b-9c6e-62c2f4591745',
#   'index': 17,
#   'period': 1,
#   'timestamp': '00:00:31.157',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [37.3, 55.0],
#   'duration': 0.8163,
#   'counterpress': True,
#   'related_events': ['a2ae2726-fb1e-4508-a12e-9619690f33fc',
#    'e0723b00-68ac-4441-b2b2-6d9c8f7f82b0']},
#  {'id': 'a2ae2726-fb1e-4508-a12e-9619690f33fc',
#   'index': 18,
#   'period': 1,
#   'timestamp': '00:00:31.580',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [82.6, 26.4],
#   'under_pressure': True,
#   'related_events': ['24d32d81-62fd-4c9b-9c6e-62c2f4591745',
#    '526da747-5500-47e1-a67a-742eb3bb3231']},
#  {'id': 'e0723b00-68ac-4441-b2b2-6d9c8f7f82b0',
#   'index': 19,
#   'period': 1,
#   'timestamp': '00:00:31.580',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [82.6, 26.4],
#   'duration': 1.991049,
#   'under_pressure': True,
#   'related_events': ['24d32d81-62fd-4c9b-9c6e-62c2f4591745',
#    'a2ae2726-fb1e-4508-a12e-9619690f33fc',
#    'b4ee99de-a57c-4baa-9201-948722afdb53',
#    'e77bce2b-6c5f-44b8-8813-a1aeb5506b0c'],
#   'carry': {'end_location': [75.9, 21.7]}},
#  {'id': 'b4ee99de-a57c-4baa-9201-948722afdb53',
#   'index': 20,
#   'period': 1,
#   'timestamp': '00:00:32.637',
#   'minute': 0,
#   'second': 32,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 4949, 'name': 'Rose Lavelle'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [40.1, 54.8],
#   'duration': 1.2262,
#   'counterpress': True,
#   'related_events': ['e0723b00-68ac-4441-b2b2-6d9c8f7f82b0',
#    'e77bce2b-6c5f-44b8-8813-a1aeb5506b0c']},
#  {'id': 'e77bce2b-6c5f-44b8-8813-a1aeb5506b0c',
#   'index': 21,
#   'period': 1,
#   'timestamp': '00:00:33.571',
#   'minute': 0,
#   'second': 33,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [75.9, 21.7],
#   'duration': 1.035486,
#   'under_pressure': True,
#   'related_events': ['b4ee99de-a57c-4baa-9201-948722afdb53',
#    'bb2a961d-17c4-4710-8cf9-9447ccfc442c'],
#   'pass': {'recipient': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#    'length': 20.14572,
#    'angle': -1.2631736,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [82.0, 2.5],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'bb2a961d-17c4-4710-8cf9-9447ccfc442c',
#   'index': 22,
#   'period': 1,
#   'timestamp': '00:00:34.607',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [82.0, 2.5],
#   'related_events': ['e77bce2b-6c5f-44b8-8813-a1aeb5506b0c']},
#  {'id': '393611fb-317b-4169-9011-c6c2ef809969',
#   'index': 23,
#   'period': 1,
#   'timestamp': '00:00:34.607',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [82.0, 2.5],
#   'duration': 1.291737,
#   'related_events': ['8036f29b-3ada-4958-8c0e-40bc8af59a3d',
#    'bb2a961d-17c4-4710-8cf9-9447ccfc442c'],
#   'carry': {'end_location': [82.0, 2.5]}},
#  {'id': '8036f29b-3ada-4958-8c0e-40bc8af59a3d',
#   'index': 24,
#   'period': 1,
#   'timestamp': '00:00:35.899',
#   'minute': 0,
#   'second': 35,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [82.0, 2.5],
#   'duration': 3.315928,
#   'related_events': ['26ab482b-bb1e-4db4-b5b8-6b11151f317a'],
#   'pass': {'recipient': {'id': 10155, 'name': 'María Pilar León Cebrián'},
#    'length': 41.367256,
#    'angle': 2.6779451,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [45.0, 21.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '26ab482b-bb1e-4db4-b5b8-6b11151f317a',
#   'index': 25,
#   'period': 1,
#   'timestamp': '00:00:39.215',
#   'minute': 0,
#   'second': 39,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10155, 'name': 'María Pilar León Cebrián'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [45.0, 21.0],
#   'related_events': ['8036f29b-3ada-4958-8c0e-40bc8af59a3d']},
#  {'id': 'b7b14200-21b6-49d9-91fa-ab0a857756e0',
#   'index': 26,
#   'period': 1,
#   'timestamp': '00:00:39.215',
#   'minute': 0,
#   'second': 39,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10155, 'name': 'María Pilar León Cebrián'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [45.0, 21.0],
#   'duration': 4.7145,
#   'related_events': ['26ab482b-bb1e-4db4-b5b8-6b11151f317a',
#    'df4ea77b-e73d-45a5-ba1c-abd81d088fee'],
#   'carry': {'end_location': [48.5, 21.4]}},
#  {'id': 'df4ea77b-e73d-45a5-ba1c-abd81d088fee',
#   'index': 27,
#   'period': 1,
#   'timestamp': '00:00:43.929',
#   'minute': 0,
#   'second': 43,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10155, 'name': 'María Pilar León Cebrián'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [48.5, 21.4],
#   'duration': 4.391938,
#   'related_events': ['b676e077-66e8-4be7-91e3-90719c0986be'],
#   'pass': {'recipient': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#    'length': 65.6282,
#    'angle': -0.06251386,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [114.0, 17.3],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'b676e077-66e8-4be7-91e3-90719c0986be',
#   'index': 28,
#   'period': 1,
#   'timestamp': '00:00:48.321',
#   'minute': 0,
#   'second': 48,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [114.0, 17.3],
#   'related_events': ['df4ea77b-e73d-45a5-ba1c-abd81d088fee']},
#  {'id': '901af92f-ea85-427b-9118-f68414f7c087',
#   'index': 29,
#   'period': 1,
#   'timestamp': '00:00:48.321',
#   'minute': 0,
#   'second': 48,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [114.0, 17.3],
#   'duration': 0.904162,
#   'related_events': ['989a7fb7-a51f-49c8-89aa-2c7f90ad1139',
#    'b676e077-66e8-4be7-91e3-90719c0986be'],
#   'carry': {'end_location': [114.4, 19.7]}},
#  {'id': '989a7fb7-a51f-49c8-89aa-2c7f90ad1139',
#   'index': 30,
#   'period': 1,
#   'timestamp': '00:00:49.225',
#   'minute': 0,
#   'second': 49,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [114.4, 19.7],
#   'duration': 0.9193,
#   'related_events': ['00184058-df21-477b-b6e2-aaebfb1aa743',
#    'dedd31a2-51ad-47b6-9b19-3ad8c8ecc900'],
#   'pass': {'recipient': {'id': 25513, 'name': 'Lucía García Córdoba'},
#    'length': 18.909521,
#    'angle': 1.6025317,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [113.8, 38.6],
#    'cross': True,
#    'cut_back': True,
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '00184058-df21-477b-b6e2-aaebfb1aa743',
#   'index': 31,
#   'period': 1,
#   'timestamp': '00:00:50.144',
#   'minute': 0,
#   'second': 50,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [108.3, 45.6],
#   'related_events': ['989a7fb7-a51f-49c8-89aa-2c7f90ad1139'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'dedd31a2-51ad-47b6-9b19-3ad8c8ecc900',
#   'index': 32,
#   'period': 1,
#   'timestamp': '00:00:50.144',
#   'minute': 0,
#   'second': 50,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5030, 'name': 'Becky Sauerbrunn'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [7.2, 42.4],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['989a7fb7-a51f-49c8-89aa-2c7f90ad1139'],
#   'clearance': {'right_foot': True,
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '60cfe5aa-01c2-4423-a7af-8ce1cc26a507',
#   'index': 33,
#   'period': 1,
#   'timestamp': '00:00:51.589',
#   'minute': 0,
#   'second': 51,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [104.0, 31.5],
#   'duration': 0.0},
#  {'id': '5cb5dc0c-d2ff-481e-b387-ad081ba389e1',
#   'index': 34,
#   'period': 1,
#   'timestamp': '00:00:51.681',
#   'minute': 0,
#   'second': 51,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [102.8, 30.1],
#   'duration': 0.4276,
#   'related_events': ['64c702e7-77fa-4230-8a36-cf36437d6d02',
#    '70c9666d-df9a-4d28-a330-1cb192c69e11'],
#   'shot': {'statsbomb_xg': 0.06885096,
#    'end_location': [113.5, 35.8],
#    'technique': {'id': 93, 'name': 'Normal'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'first_time': True,
#    'freeze_frame': [{'location': [109.1, 39.9],
#      'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [91.5, 39.6],
#      'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [112.1, 41.9],
#      'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [118.7, 36.8],
#      'player': {'id': 5100, 'name': 'Alyssa Naeher'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [106.5, 28.5],
#      'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [118.2, 20.1],
#      'player': {'id': 10143, 'name': 'Alexia Putellas Segura'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [112.9, 42.2],
#      'player': {'id': 5088, 'name': 'Crystal Alyssia Dunn'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [113.6, 37.0],
#      'player': {'id': 5030, 'name': 'Becky Sauerbrunn'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [111.0, 28.2],
#      'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [113.3, 31.0],
#      'player': {'id': 5021, 'name': 'Kelley O"Hara'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [101.4, 28.7],
#      'player': {'id': 4949, 'name': 'Rose Lavelle'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [108.5, 39.0],
#      'player': {'id': 6811, 'name': 'Julie Ertz'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [108.3, 41.5],
#      'player': {'id': 5087, 'name': 'Samantha Mewis'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False}]}},
#  {'id': '70c9666d-df9a-4d28-a330-1cb192c69e11',
#   'index': 35,
#   'period': 1,
#   'timestamp': '00:00:52.109',
#   'minute': 0,
#   'second': 52,
#   'type': {'id': 6, 'name': 'Block'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5030, 'name': 'Becky Sauerbrunn'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [6.6, 44.3],
#   'duration': 0.0,
#   'related_events': ['5cb5dc0c-d2ff-481e-b387-ad081ba389e1']},
#  {'id': '64c702e7-77fa-4230-8a36-cf36437d6d02',
#   'index': 36,
#   'period': 1,
#   'timestamp': '00:00:52.149',
#   'minute': 0,
#   'second': 52,
#   'type': {'id': 23, 'name': 'Goal Keeper'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5100, 'name': 'Alyssa Naeher'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [1.4, 43.3],
#   'duration': 0.0,
#   'related_events': ['5cb5dc0c-d2ff-481e-b387-ad081ba389e1'],
#   'goalkeeper': {'end_location': [1.4, 43.3],
#    'position': {'id': 44, 'name': 'Set'},
#    'type': {'id': 32, 'name': 'Shot Faced'}}},
#  {'id': 'a6e1554c-034f-4185-8251-78883c55de13',
#   'index': 37,
#   'period': 1,
#   'timestamp': '00:00:53.248',
#   'minute': 0,
#   'second': 53,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [103.1, 27.1],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['7fc741b0-9a68-4d9a-b381-b38754e63ec4'],
#   'duel': {'type': {'id': 10, 'name': 'Aerial Lost'}}},
#  {'id': '7fc741b0-9a68-4d9a-b381-b38754e63ec4',
#   'index': 38,
#   'period': 1,
#   'timestamp': '00:00:53.248',
#   'minute': 0,
#   'second': 53,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 4949, 'name': 'Rose Lavelle'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [17.9, 53.9],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['a6e1554c-034f-4185-8251-78883c55de13'],
#   'clearance': {'aerial_won': True,
#    'head': True,
#    'body_part': {'id': 37, 'name': 'Head'}}},
#  {'id': 'a65a8833-be70-455c-b7b2-c2f3edade594',
#   'index': 39,
#   'period': 1,
#   'timestamp': '00:00:55.163',
#   'minute': 0,
#   'second': 55,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [84.6, 28.2],
#   'duration': 1.1593,
#   'related_events': ['28f30330-2530-4108-999c-46a88b31116a',
#    'e79f21a4-ee55-4c21-bb2f-e4429888b580']},
#  {'id': 'e79f21a4-ee55-4c21-bb2f-e4429888b580',
#   'index': 40,
#   'period': 1,
#   'timestamp': '00:00:56.295',
#   'minute': 0,
#   'second': 56,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5085, 'name': 'Alex Morgan'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [39.9, 52.8],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['a65a8833-be70-455c-b7b2-c2f3edade594']},
#  {'id': '28f30330-2530-4108-999c-46a88b31116a',
#   'index': 41,
#   'period': 1,
#   'timestamp': '00:00:56.295',
#   'minute': 0,
#   'second': 56,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5085, 'name': 'Alex Morgan'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [39.9, 52.8],
#   'duration': 1.4446,
#   'under_pressure': True,
#   'related_events': ['092b0f2e-1978-435e-90a6-85b5b53b3546',
#    '65b6a44f-2878-410b-b9ab-c4626378cdfd',
#    'a65a8833-be70-455c-b7b2-c2f3edade594',
#    'e79f21a4-ee55-4c21-bb2f-e4429888b580'],
#   'carry': {'end_location': [39.2, 51.5]}},
#  {'id': '65b6a44f-2878-410b-b9ab-c4626378cdfd',
#   'index': 42,
#   'period': 1,
#   'timestamp': '00:00:57.740',
#   'minute': 0,
#   'second': 57,
#   'type': {'id': 22, 'name': 'Foul Committed'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [81.8, 29.5],
#   'duration': 0.0,
#   'counterpress': True,
#   'related_events': ['092b0f2e-1978-435e-90a6-85b5b53b3546',
#    '28f30330-2530-4108-999c-46a88b31116a']},
#  {'id': '092b0f2e-1978-435e-90a6-85b5b53b3546',
#   'index': 43,
#   'period': 1,
#   'timestamp': '00:00:57.740',
#   'minute': 0,
#   'second': 57,
#   'type': {'id': 21, 'name': 'Foul Won'},
#   'possession': 5,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5085, 'name': 'Alex Morgan'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [39.2, 51.5],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['65b6a44f-2878-410b-b9ab-c4626378cdfd']},
#  {'id': 'ec3b07f5-54c4-4efa-ade9-2ff2ab831a22',
#   'index': 44,
#   'period': 1,
#   'timestamp': '00:01:21.122',
#   'minute': 1,
#   'second': 21,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'off_camera': True,
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 6811, 'name': 'Julie Ertz'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [39.9, 51.5],
#   'duration': 3.178505,
#   'related_events': ['2fb3e8e1-2f36-4b42-a827-018f59cfd74d'],
#   'pass': {'length': 55.15143,
#    'angle': -0.3286312,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [92.1, 33.7],
#    'type': {'id': 62, 'name': 'Free Kick'},
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '2fb3e8e1-2f36-4b42-a827-018f59cfd74d',
#   'index': 45,
#   'period': 1,
#   'timestamp': '00:01:24.300',
#   'minute': 1,
#   'second': 24,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'off_camera': True,
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10165, 'name': 'Irene Paredes Hernandez'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [28.9, 47.3],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['ec3b07f5-54c4-4efa-ade9-2ff2ab831a22'],
#   'clearance': {'head': True, 'body_part': {'id': 37, 'name': 'Head'}}},
#  {'id': 'e2086404-0843-4f56-8ac5-ca87bcfd25ad',
#   'index': 46,
#   'period': 1,
#   'timestamp': '00:01:25.505',
#   'minute': 1,
#   'second': 25,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5085, 'name': 'Alex Morgan'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [89.3, 36.5],
#   'duration': 1.5097,
#   'related_events': ['31bca2a5-2cf6-41fa-a8d0-5905273fa143',
#    'bb972dd6-91e6-4e79-a96d-1ea89e9913e4'],
#   'pass': {'recipient': {'id': 8298, 'name': 'Megan Rapinoe'},
#    'length': 18.462124,
#    'angle': -0.91212845,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [100.6, 21.9],
#    'body_part': {'id': 37, 'name': 'Head'},
#    'type': {'id': 66, 'name': 'Recovery'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'bb972dd6-91e6-4e79-a96d-1ea89e9913e4',
#   'index': 47,
#   'period': 1,
#   'timestamp': '00:01:27.014',
#   'minute': 1,
#   'second': 27,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [94.3, 23.9],
#   'related_events': ['e2086404-0843-4f56-8ac5-ca87bcfd25ad'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '31bca2a5-2cf6-41fa-a8d0-5905273fa143',
#   'index': 48,
#   'period': 1,
#   'timestamp': '00:01:27.014',
#   'minute': 1,
#   'second': 27,
#   'type': {'id': 9, 'name': 'Clearance'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [20.4, 59.1],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['e2086404-0843-4f56-8ac5-ca87bcfd25ad'],
#   'clearance': {'right_foot': True,
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '7e64f745-e2a5-46f5-8a0b-7ba111ad2829',
#   'index': 49,
#   'period': 1,
#   'timestamp': '00:01:28.929',
#   'minute': 1,
#   'second': 28,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [40.2, 54.5],
#   'duration': 2.2144,
#   'related_events': ['39853f09-4a2c-4e45-a451-c973eade207a'],
#   'pass': {'recipient': {'id': 25513, 'name': 'Lucía García Córdoba'},
#    'length': 17.366634,
#    'angle': 1.709436,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [37.8, 71.7],
#    'body_part': {'id': 37, 'name': 'Head'},
#    'type': {'id': 66, 'name': 'Recovery'}}},
#  {'id': '6ee905f2-f3cc-4396-891f-6a1e904bf53e',
#   'index': 50,
#   'period': 1,
#   'timestamp': '00:01:29.800',
#   'minute': 1,
#   'second': 29,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5088, 'name': 'Crystal Alyssia Dunn'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [88.2, 10.1],
#   'duration': 1.6463,
#   'counterpress': True,
#   'related_events': ['3893286d-2ae9-49a4-a110-7081fca0b7b6',
#    '39853f09-4a2c-4e45-a451-c973eade207a',
#    'd0eafa03-2b6d-41ad-9701-1372171466af']},
#  {'id': '39853f09-4a2c-4e45-a451-c973eade207a',
#   'index': 51,
#   'period': 1,
#   'timestamp': '00:01:31.144',
#   'minute': 1,
#   'second': 31,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [37.8, 71.7],
#   'under_pressure': True,
#   'related_events': ['6ee905f2-f3cc-4396-891f-6a1e904bf53e',
#    '7e64f745-e2a5-46f5-8a0b-7ba111ad2829']},
#  {'id': 'd0eafa03-2b6d-41ad-9701-1372171466af',
#   'index': 52,
#   'period': 1,
#   'timestamp': '00:01:31.144',
#   'minute': 1,
#   'second': 31,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [37.8, 71.7],
#   'duration': 0.04,
#   'under_pressure': True,
#   'related_events': ['3893286d-2ae9-49a4-a110-7081fca0b7b6',
#    '39853f09-4a2c-4e45-a451-c973eade207a',
#    '6ee905f2-f3cc-4396-891f-6a1e904bf53e'],
#   'carry': {'end_location': [35.6, 74.3]}},
#  {'id': '3893286d-2ae9-49a4-a110-7081fca0b7b6',
#   'index': 53,
#   'period': 1,
#   'timestamp': '00:01:31.184',
#   'minute': 1,
#   'second': 31,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 25513, 'name': 'Lucía García Córdoba'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [35.6, 74.3],
#   'duration': 5.5652,
#   'under_pressure': True,
#   'related_events': ['6ee905f2-f3cc-4396-891f-6a1e904bf53e',
#    '81b55770-f62c-44f8-b4d4-2c784aa1a76d'],
#   'pass': {'length': 54.18533,
#    'angle': -0.23468359,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [88.3, 61.7],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '81b55770-f62c-44f8-b4d4-2c784aa1a76d',
#   'index': 54,
#   'period': 1,
#   'timestamp': '00:01:36.749',
#   'minute': 1,
#   'second': 36,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5030, 'name': 'Becky Sauerbrunn'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [32.7, 19.3],
#   'duration': 1.451476,
#   'related_events': ['2f9e8ba6-3867-493c-b586-21f0f6a87d2a',
#    '3893286d-2ae9-49a4-a110-7081fca0b7b6'],
#   'pass': {'recipient': {'id': 5081, 'name': 'Abby Dahlkemper'},
#    'length': 21.102606,
#    'angle': 1.3120254,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [38.1, 39.7],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'type': {'id': 66, 'name': 'Recovery'}}},
#  {'id': '2f9e8ba6-3867-493c-b586-21f0f6a87d2a',
#   'index': 55,
#   'period': 1,
#   'timestamp': '00:01:38.200',
#   'minute': 1,
#   'second': 38,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [38.1, 39.7],
#   'related_events': ['81b55770-f62c-44f8-b4d4-2c784aa1a76d']},
#  {'id': '17d41746-2734-47ee-b430-68dd8c5a4d56',
#   'index': 56,
#   'period': 1,
#   'timestamp': '00:01:38.200',
#   'minute': 1,
#   'second': 38,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [38.1, 39.7],
#   'duration': 1.987024,
#   'related_events': ['0dfb2894-1ee6-4185-b3ac-782c4a8b93e9',
#    '2f9e8ba6-3867-493c-b586-21f0f6a87d2a'],
#   'carry': {'end_location': [48.6, 43.7]}},
#  {'id': '0dfb2894-1ee6-4185-b3ac-782c4a8b93e9',
#   'index': 57,
#   'period': 1,
#   'timestamp': '00:01:40.188',
#   'minute': 1,
#   'second': 40,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5081, 'name': 'Abby Dahlkemper'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [48.6, 43.7],
#   'duration': 2.6163,
#   'related_events': ['3ad20739-9630-4fa8-aa49-06ed780c97f7'],
#   'pass': {'recipient': {'id': 8298, 'name': 'Megan Rapinoe'},
#    'length': 54.432526,
#    'angle': -0.4792585,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [96.9, 18.6],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '3ad20739-9630-4fa8-aa49-06ed780c97f7',
#   'index': 58,
#   'period': 1,
#   'timestamp': '00:01:42.804',
#   'minute': 1,
#   'second': 42,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [96.9, 18.6],
#   'related_events': ['0dfb2894-1ee6-4185-b3ac-782c4a8b93e9']},
#  {'id': '58eec6fc-b409-4d14-b815-3e3d089aea4a',
#   'index': 59,
#   'period': 1,
#   'timestamp': '00:01:42.804',
#   'minute': 1,
#   'second': 42,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [96.9, 18.6],
#   'duration': 0.5716,
#   'related_events': ['2b09aa42-2726-4b1d-bb68-8db38695576d',
#    '3ad20739-9630-4fa8-aa49-06ed780c97f7'],
#   'carry': {'end_location': [95.6, 19.1]}},
#  {'id': '2b09aa42-2726-4b1d-bb68-8db38695576d',
#   'index': 60,
#   'period': 1,
#   'timestamp': '00:01:43.375',
#   'minute': 1,
#   'second': 43,
#   'type': {'id': 38, 'name': 'Miscontrol'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [95.6, 19.1],
#   'duration': 0.0},
#  {'id': '79a30cd3-157c-4306-aabe-0c8c9a75a973',
#   'index': 61,
#   'period': 1,
#   'timestamp': '00:01:43.497',
#   'minute': 1,
#   'second': 43,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [25.8, 60.8],
#   'duration': 1.854021,
#   'related_events': ['654430cc-9bc2-40ec-9f91-228f69bce61f']},
#  {'id': '654430cc-9bc2-40ec-9f91-228f69bce61f',
#   'index': 62,
#   'period': 1,
#   'timestamp': '00:01:44.431',
#   'minute': 1,
#   'second': 44,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 6,
#   'possession_team': {'id': 1214, 'name': "United States Women's"},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [113.0, 7.7],
#   'duration': 1.8389,
#   'under_pressure': True,
#   'related_events': ['0ac02c6b-b274-4fd9-8e7b-6ca58693e2e4',
#    '79a30cd3-157c-4306-aabe-0c8c9a75a973']},
#  {'id': '0ac02c6b-b274-4fd9-8e7b-6ca58693e2e4',
#   'index': 63,
#   'period': 1,
# ...
#    'dec5acb5-adab-44a1-bb11-c70102557017'],
#   'carry': {'end_location': [74.7, 9.5]}},
#  {'id': 'dec5acb5-adab-44a1-bb11-c70102557017',
#   'index': 978,
#   'period': 1,
#   'timestamp': '00:29:05.095',
#   'minute': 29,
#   'second': 5,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 6811, 'name': 'Julie Ertz'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [74.7, 9.5],
#   'duration': 0.624635,
#   'related_events': ['a3023d20-0fb2-4dcf-8e90-561aaefa4a17'],
#   'pass': {'recipient': {'id': 8298, 'name': 'Megan Rapinoe'},
#    'length': 12.617845,
#    'angle': 0.3142319,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [86.7, 13.4],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'a3023d20-0fb2-4dcf-8e90-561aaefa4a17',
#   'index': 979,
#   'period': 1,
#   'timestamp': '00:29:05.719',
#   'minute': 29,
#   'second': 5,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [86.7, 13.4],
#   'related_events': ['dec5acb5-adab-44a1-bb11-c70102557017']},
#  {'id': 'b67f77e7-04d3-44ec-b734-b3011fdf926d',
#   'index': 980,
#   'period': 1,
#   'timestamp': '00:29:05.719',
#   'minute': 29,
#   'second': 5,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [86.7, 13.4],
#   'duration': 4.520665,
#   'under_pressure': True,
#   'related_events': ['2ada59fe-1065-4b81-ac87-e7676c877a91',
#    'a3023d20-0fb2-4dcf-8e90-561aaefa4a17',
#    'baf5290d-025d-4245-ad67-09549c575fa2'],
#   'carry': {'end_location': [100.6, 21.2]}},
#  {'id': '2ada59fe-1065-4b81-ac87-e7676c877a91',
#   'index': 981,
#   'period': 1,
#   'timestamp': '00:29:09.422',
#   'minute': 29,
#   'second': 9,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [20.6, 53.9],
#   'duration': 0.477809,
#   'counterpress': True,
#   'related_events': ['b67f77e7-04d3-44ec-b734-b3011fdf926d']},
#  {'id': 'baf5290d-025d-4245-ad67-09549c575fa2',
#   'index': 982,
#   'period': 1,
#   'timestamp': '00:29:10.240',
#   'minute': 29,
#   'second': 10,
#   'type': {'id': 3, 'name': 'Dispossessed'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 8298, 'name': 'Megan Rapinoe'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [100.6, 21.2],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['4c64337d-17e0-4afe-bb0d-9ca9cbf5049a']},
#  {'id': '4c64337d-17e0-4afe-bb0d-9ca9cbf5049a',
#   'index': 983,
#   'period': 1,
#   'timestamp': '00:29:10.240',
#   'minute': 29,
#   'second': 10,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [20.4, 59.8],
#   'duration': 0.0,
#   'under_pressure': True,
#   'counterpress': True,
#   'related_events': ['baf5290d-025d-4245-ad67-09549c575fa2'],
#   'duel': {'type': {'id': 11, 'name': 'Tackle'},
#    'outcome': {'id': 16, 'name': 'Success In Play'}}},
#  {'id': 'e9c4e9a2-72b4-49eb-ab50-7e292e4eb8f9',
#   'index': 984,
#   'period': 1,
#   'timestamp': '00:29:12.009',
#   'minute': 29,
#   'second': 12,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [23.2, 60.4],
#   'duration': 0.0},
#  {'id': 'e7be7144-5541-489e-a256-a55d64e1d046',
#   'index': 985,
#   'period': 1,
#   'timestamp': '00:29:12.009',
#   'minute': 29,
#   'second': 12,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [23.2, 60.4],
#   'duration': 1.687903,
#   'related_events': ['e9c4e9a2-72b4-49eb-ab50-7e292e4eb8f9',
#    'fa0ce1f2-52b5-4b0b-a532-68643cd4621b'],
#   'carry': {'end_location': [27.6, 64.1]}},
#  {'id': 'fa0ce1f2-52b5-4b0b-a532-68643cd4621b',
#   'index': 986,
#   'period': 1,
#   'timestamp': '00:29:13.697',
#   'minute': 29,
#   'second': 13,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10158, 'name': 'María Victoria Losada Gómez'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [27.6, 64.1],
#   'duration': 0.8422,
#   'related_events': ['b80f0caa-98bc-41e4-a8ea-1ff0ad5e6190'],
#   'pass': {'recipient': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#    'length': 10.34698,
#    'angle': 2.1775634,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [21.7, 72.6],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'b80f0caa-98bc-41e4-a8ea-1ff0ad5e6190',
#   'index': 987,
#   'period': 1,
#   'timestamp': '00:29:14.539',
#   'minute': 29,
#   'second': 14,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [21.7, 72.6],
#   'related_events': ['fa0ce1f2-52b5-4b0b-a532-68643cd4621b']},
#  {'id': '36d2d34d-65ed-439e-87cb-2baee8bcb7d0',
#   'index': 988,
#   'period': 1,
#   'timestamp': '00:29:14.539',
#   'minute': 29,
#   'second': 14,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [21.7, 72.6],
#   'duration': 0.04,
#   'related_events': ['7ca2cb66-041d-4a31-b8f1-2beb93f61cc1',
#    'b80f0caa-98bc-41e4-a8ea-1ff0ad5e6190'],
#   'carry': {'end_location': [21.7, 72.6]}},
#  {'id': '7ca2cb66-041d-4a31-b8f1-2beb93f61cc1',
#   'index': 989,
#   'period': 1,
#   'timestamp': '00:29:14.579',
#   'minute': 29,
#   'second': 14,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10200, 'name': 'Marta Corredera Rueda'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [21.7, 72.6],
#   'duration': 1.605,
#   'related_events': ['0124769a-ce2d-4fd8-8182-b61de5aeacd2',
#    'ae35c9d8-7654-4a45-9c70-1e3833f6f30e'],
#   'pass': {'recipient': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#    'length': 18.305191,
#    'angle': -0.97976345,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [31.9, 57.4],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '0124769a-ce2d-4fd8-8182-b61de5aeacd2',
#   'index': 990,
#   'period': 1,
#   'timestamp': '00:29:16.184',
#   'minute': 29,
#   'second': 16,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10202, 'name': 'Virginia Torrecilla Reyes'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'location': [31.5, 56.3],
#   'related_events': ['7ca2cb66-041d-4a31-b8f1-2beb93f61cc1'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'ae35c9d8-7654-4a45-9c70-1e3833f6f30e',
#   'index': 991,
#   'period': 1,
#   'timestamp': '00:29:16.184',
#   'minute': 29,
#   'second': 16,
#   'type': {'id': 10, 'name': 'Interception'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5085, 'name': 'Alex Morgan'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [89.1, 23.6],
#   'duration': 0.0,
#   'related_events': ['7ca2cb66-041d-4a31-b8f1-2beb93f61cc1'],
#   'interception': {'outcome': {'id': 13, 'name': 'Lost In Play'}}},
#  {'id': '60f7700e-dc3a-4e64-986f-c31430faba97',
#   'index': 992,
#   'period': 1,
#   'timestamp': '00:29:17.582',
#   'minute': 29,
#   'second': 17,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [38.7, 51.3],
#   'duration': 0.0},
#  {'id': 'fe875727-ec18-4437-91f8-da7b36e64572',
#   'index': 993,
#   'period': 1,
#   'timestamp': '00:29:17.582',
#   'minute': 29,
#   'second': 17,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [38.7, 51.3],
#   'duration': 1.658125,
#   'related_events': ['60f7700e-dc3a-4e64-986f-c31430faba97',
#    '7e84d5d3-395f-4b31-a4cb-0dde10c7ea7f'],
#   'carry': {'end_location': [36.7, 49.1]}},
#  {'id': '7e84d5d3-395f-4b31-a4cb-0dde10c7ea7f',
#   'index': 994,
#   'period': 1,
#   'timestamp': '00:29:19.240',
#   'minute': 29,
#   'second': 19,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [36.7, 49.1],
#   'duration': 1.299698,
#   'related_events': ['d3c39c5b-1818-4117-b3ed-908914389652'],
#   'pass': {'recipient': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#    'length': 18.146626,
#    'angle': -1.4990963,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [38.0, 31.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'd3c39c5b-1818-4117-b3ed-908914389652',
#   'index': 995,
#   'period': 1,
#   'timestamp': '00:29:20.540',
#   'minute': 29,
#   'second': 20,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [38.0, 31.0],
#   'related_events': ['7e84d5d3-395f-4b31-a4cb-0dde10c7ea7f']},
#  {'id': '391eb479-aaba-4b5b-b4aa-b6248f6bc3d6',
#   'index': 996,
#   'period': 1,
#   'timestamp': '00:29:20.540',
#   'minute': 29,
#   'second': 20,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [38.0, 31.0],
#   'duration': 1.901102,
#   'under_pressure': True,
#   'related_events': ['a2c65451-59b4-4282-8525-3f5b0b554289',
#    'd3c39c5b-1818-4117-b3ed-908914389652',
#    'd443ab2f-ca5e-4c5c-a23d-00635bc00318'],
#   'carry': {'end_location': [50.0, 31.0]}},
#  {'id': 'a2c65451-59b4-4282-8525-3f5b0b554289',
#   'index': 997,
#   'period': 1,
#   'timestamp': '00:29:21.934',
#   'minute': 29,
#   'second': 21,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 1214, 'name': "United States Women's"},
#   'player': {'id': 5021, 'name': 'Kelley O"Hara'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [64.0, 52.2],
#   'duration': 0.6791,
#   'related_events': ['391eb479-aaba-4b5b-b4aa-b6248f6bc3d6',
#    'd443ab2f-ca5e-4c5c-a23d-00635bc00318']},
#  {'id': 'd443ab2f-ca5e-4c5c-a23d-00635bc00318',
#   'index': 998,
#   'period': 1,
#   'timestamp': '00:29:22.441',
#   'minute': 29,
#   'second': 22,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 15287, 'name': 'Patricia Guijarro Gutiérrez'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [50.0, 31.0],
#   'duration': 0.878,
#   'under_pressure': True,
#   'related_events': ['a2c65451-59b4-4282-8525-3f5b0b554289',
#    'ff2c3ac9-f5c2-46bf-9533-53c103da8cd8'],
#   'pass': {'recipient': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#    'length': 12.3878975,
#    'angle': 0.46003753,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [61.1, 36.5],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'ff2c3ac9-f5c2-46bf-9533-53c103da8cd8',
#   'index': 999,
#   'period': 1,
#   'timestamp': '00:29:23.319',
#   'minute': 29,
#   'second': 23,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [61.1, 36.5],
#   'related_events': ['d443ab2f-ca5e-4c5c-a23d-00635bc00318']},
#  {'id': '08f77615-e31d-4f3f-8fc1-9af4ee4b11d8',
#   'index': 1000,
#   'period': 1,
#   'timestamp': '00:29:23.319',
#   'minute': 29,
#   'second': 23,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 63,
#   'possession_team': {'id': 863, 'name': "Spain Women's"},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 863, 'name': "Spain Women's"},
#   'player': {'id': 10151, 'name': 'Jennifer Hermoso Fuentes'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [61.1, 36.5],
#   'duration': 0.040000003,
#   'related_events': ['783c2a77-42c1-4b13-adf7-7bd0e14648cc',
#    'ff2c3ac9-f5c2-46bf-9533-53c103da8cd8'],
#   'carry': {'end_location': [62.8, 35.6]}},
#  ...]

# %%
#get the nested structure into a dataframe 
#store the dataframe in a dictionary with the match id as key (remove '.json' from string)
from pandas.io.json import json_normalize
df = json_normalize(data, sep = "_").assign(match_id = file_name[:-5])
# Out:
# /var/folders/bp/v78k11s50pdbmf3gy9nync040000gn/T/ipykernel_81558/4104332721.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(data, sep = "_").assign(match_id = file_name[:-5])

# %%
df
# Out:
#                                         id  index  period     timestamp  \
# 0     413582c3-a655-4821-968f-6bdf53906d16      1       1  00:00:00.000
# 1     bd1acd1d-62c5-4f5b-b589-1414f88804cc      2       1  00:00:00.000
# 2     4205c4b8-d57f-47a7-9e42-6c148dafdb06      3       1  00:00:00.000
# 3     6223be74-60bb-4248-b1d1-02ecf9ce337e      4       1  00:00:00.000
# 4     6c519b96-4646-47ca-adcf-2385bddd79da      5       1  00:00:00.689
# ...                                    ...    ...     ...           ...
# 3050  f3db87d6-019f-4d4a-b5b9-2317eb84dbce   3051       2  00:53:03.907
# 3051  ee08692e-d9a9-446c-b345-65bb2902ebc9   3052       2  00:53:05.769
# 3052  4341dd04-2e65-471e-8d26-d8ed2fa51f91   3053       2  00:53:08.000
# 3053  b9aea0e5-8af1-46af-b4ba-558514cb2bb9   3054       2  00:53:10.262
# 3054  4df239a8-9f6e-4d54-baf8-888053536592   3055       2  00:53:10.262
#
#       minute  second  possession  duration  type_id      type_name  ...  \
# 0          0       0           1    0.0000       35    Starting XI  ...
# 1          0       0           1    0.0000       35    Starting XI  ...
# 2          0       0           1    0.0000       18     Half Start  ...
# 3          0       0           1    0.0000       18     Half Start  ...
# 4          0       0           2    1.8506       30           Pass  ...
# ...      ...     ...         ...       ...      ...            ...  ...
# 3050      98       3         177    1.8614       43          Carry  ...
# 3051      98       5         177    2.2308       30           Pass  ...
# 3052      98       8         177    0.0000        2  Ball Recovery  ...
# 3053      98      10         177    0.0000       34       Half End  ...
# 3054      98      10         177    0.0000       34       Half End  ...
#
#       injury_stoppage_in_chain substitution_outcome_id  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 3050                       NaN                     NaN
# 3051                       NaN                     NaN
# 3052                       NaN                     NaN
# 3053                       NaN                     NaN
# 3054                       NaN                     NaN
#
#       substitution_outcome_name substitution_replacement_id  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 3050                        NaN                         NaN
# 3051                        NaN                         NaN
# 3052                        NaN                         NaN
# 3053                        NaN                         NaN
# 3054                        NaN                         NaN
#
#       substitution_replacement_name foul_committed_card_id  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 3050                            NaN                    NaN
# 3051                            NaN                    NaN
# 3052                            NaN                    NaN
# 3053                            NaN                    NaN
# 3054                            NaN                    NaN
#
#       foul_committed_card_name 50_50_outcome_id 50_50_outcome_name match_id
# 0                          NaN              NaN                NaN    69161
# 1                          NaN              NaN                NaN    69161
# 2                          NaN              NaN                NaN    69161
# 3                          NaN              NaN                NaN    69161
# 4                          NaN              NaN                NaN    69161
# ...                        ...              ...                ...      ...
# 3050                       NaN              NaN                NaN    69161
# 3051                       NaN              NaN                NaN    69161
# 3052                       NaN              NaN                NaN    69161
# 3053                       NaN              NaN                NaN    69161
# 3054                       NaN              NaN                NaN    69161
#
# [3055 rows x 116 columns]

# %%
set(df['type_name'])
# Out:
# {'50/50',
#  'Ball Receipt*',
#  'Ball Recovery',
#  'Block',
#  'Carry',
#  'Clearance',
#  'Dispossessed',
#  'Dribble',
#  'Dribbled Past',
#  'Duel',
#  'Error',
#  'Foul Committed',
#  'Foul Won',
#  'Goal Keeper',
#  'Half End',
#  'Half Start',
#  'Injury Stoppage',
#  'Interception',
#  'Miscontrol',
#  'Pass',
#  'Player Off',
#  'Player On',
#  'Pressure',
#  'Referee Ball-Drop',
#  'Shield',
#  'Shot',
#  'Starting XI',
#  'Substitution',
#  'Tactical Shift'}

# %%
#A dataframe of shots
shots = df.loc[df['type_name'] == 'Shot'].set_index('id')

# %%
shots
# Out:
#                                       index  period     timestamp  minute  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1     34       1  00:00:51.681       0
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe    199       1  00:06:06.236       6
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4    295       1  00:08:54.261       8
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539    346       1  00:12:48.506      12
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02    350       1  00:13:19.559      13
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e    459       1  00:16:46.329      16
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93    775       1  00:24:54.778      24
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b   1156       1  00:34:27.249      34
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb   1177       1  00:35:10.554      35
# 0458b135-c2f2-4ae5-813e-e182023add16   1851       2  00:07:58.324      52
# 3e767b66-7e5a-428e-a4a8-26af57a7639b   2060       2  00:14:29.178      59
# 97ea84d3-d429-48a4-9664-a2c2d489da12   2212       2  00:19:07.871      64
# 746bc451-30af-477a-b824-293543017741   2228       2  00:19:59.455      64
# a5a87567-a946-4860-9f5f-75436339c59d   2433       2  00:30:36.196      75
# b770310f-94c0-4397-ae2e-98d4ce86ace2   2505       2  00:33:35.925      78
#
#                                       second  possession  duration  type_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1      51           5  0.427600       16
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe       6          12  0.496300       16
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      54          19  1.359400       16
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539      48          24  0.374300       16
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02      19          25  0.341200       16
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e      46          32  0.163800       16
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93      54          50  0.442100       16
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b      27          72  1.028601       16
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb      10          74  1.428799       16
# 0458b135-c2f2-4ae5-813e-e182023add16      58         109  0.113900       16
# 3e767b66-7e5a-428e-a4a8-26af57a7639b      29         118  1.029600       16
# 97ea84d3-d429-48a4-9664-a2c2d489da12       7         126  1.129000       16
# 746bc451-30af-477a-b824-293543017741      59         128  1.209200       16
# a5a87567-a946-4860-9f5f-75436339c59d      36         138  0.458900       16
# b770310f-94c0-4397-ae2e-98d4ce86ace2      35         143  1.418400       16
#
#                                      type_name  possession_team_id  ...  \
# id                                                                  ...
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1      Shot                 863  ...
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe      Shot                1214  ...
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      Shot                1214  ...
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539      Shot                1214  ...
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02      Shot                1214  ...
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e      Shot                1214  ...
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93      Shot                1214  ...
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b      Shot                1214  ...
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb      Shot                1214  ...
# 0458b135-c2f2-4ae5-813e-e182023add16      Shot                 863  ...
# 3e767b66-7e5a-428e-a4a8-26af57a7639b      Shot                1214  ...
# 97ea84d3-d429-48a4-9664-a2c2d489da12      Shot                1214  ...
# 746bc451-30af-477a-b824-293543017741      Shot                 863  ...
# a5a87567-a946-4860-9f5f-75436339c59d      Shot                1214  ...
# b770310f-94c0-4397-ae2e-98d4ce86ace2      Shot                1214  ...
#
#                                      injury_stoppage_in_chain  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                       substitution_outcome_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                      substitution_outcome_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                       NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                       NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                       NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                       NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                       NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                       NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                       NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                       NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                       NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                       NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                       NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                       NaN
# 746bc451-30af-477a-b824-293543017741                       NaN
# a5a87567-a946-4860-9f5f-75436339c59d                       NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                       NaN
#
#                                       substitution_replacement_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                          NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                          NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                          NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                          NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                          NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                          NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                          NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                          NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                          NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                          NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                          NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                          NaN
# 746bc451-30af-477a-b824-293543017741                          NaN
# a5a87567-a946-4860-9f5f-75436339c59d                          NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                          NaN
#
#                                      substitution_replacement_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                           NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                           NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                           NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                           NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                           NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                           NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                           NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                           NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                           NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                           NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                           NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                           NaN
# 746bc451-30af-477a-b824-293543017741                           NaN
# a5a87567-a946-4860-9f5f-75436339c59d                           NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                           NaN
#
#                                       foul_committed_card_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                     NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                     NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                     NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                     NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                     NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                     NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                     NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                     NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                     NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                     NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                     NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                     NaN
# 746bc451-30af-477a-b824-293543017741                     NaN
# a5a87567-a946-4860-9f5f-75436339c59d                     NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                     NaN
#
#                                      foul_committed_card_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                      50_50_outcome_id 50_50_outcome_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1              NaN                NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe              NaN                NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4              NaN                NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539              NaN                NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02              NaN                NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e              NaN                NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93              NaN                NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b              NaN                NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb              NaN                NaN
# 0458b135-c2f2-4ae5-813e-e182023add16              NaN                NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b              NaN                NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12              NaN                NaN
# 746bc451-30af-477a-b824-293543017741              NaN                NaN
# a5a87567-a946-4860-9f5f-75436339c59d              NaN                NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2              NaN                NaN
#
#                                       match_id
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1     69161
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe     69161
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4     69161
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539     69161
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02     69161
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e     69161
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93     69161
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b     69161
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb     69161
# 0458b135-c2f2-4ae5-813e-e182023add16     69161
# 3e767b66-7e5a-428e-a4a8-26af57a7639b     69161
# 97ea84d3-d429-48a4-9664-a2c2d489da12     69161
# 746bc451-30af-477a-b824-293543017741     69161
# a5a87567-a946-4860-9f5f-75436339c59d     69161
# b770310f-94c0-4397-ae2e-98d4ce86ace2     69161
#
# [15 rows x 115 columns]

# %%
set(shots['shot_outcome_name'])
# Out:
# {'Blocked', 'Goal', 'Off T', 'Saved Off Target'}

# %%
goles = shots[shots['shot_outcome_name']=='Goal']
goles
# Out:
#                                       index  period     timestamp  minute  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe    199       1  00:06:06.236       6
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4    295       1  00:08:54.261       8
# a5a87567-a946-4860-9f5f-75436339c59d   2433       2  00:30:36.196      75
#
#                                       second  possession  duration  type_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe       6          12    0.4963       16
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      54          19    1.3594       16
# a5a87567-a946-4860-9f5f-75436339c59d      36         138    0.4589       16
#
#                                      type_name  possession_team_id  ...  \
# id                                                                  ...
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe      Shot                1214  ...
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      Shot                1214  ...
# a5a87567-a946-4860-9f5f-75436339c59d      Shot                1214  ...
#
#                                      injury_stoppage_in_chain  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                       substitution_outcome_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                      substitution_outcome_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                       NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                       NaN
# a5a87567-a946-4860-9f5f-75436339c59d                       NaN
#
#                                       substitution_replacement_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                          NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                          NaN
# a5a87567-a946-4860-9f5f-75436339c59d                          NaN
#
#                                      substitution_replacement_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                           NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                           NaN
# a5a87567-a946-4860-9f5f-75436339c59d                           NaN
#
#                                       foul_committed_card_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                     NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                     NaN
# a5a87567-a946-4860-9f5f-75436339c59d                     NaN
#
#                                      foul_committed_card_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                      50_50_outcome_id 50_50_outcome_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe              NaN                NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4              NaN                NaN
# a5a87567-a946-4860-9f5f-75436339c59d              NaN                NaN
#
#                                       match_id
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe     69161
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4     69161
# a5a87567-a946-4860-9f5f-75436339c59d     69161
#
# [3 rows x 115 columns]

# %%
goles
# Out:
#                                       index  period     timestamp  minute  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe    199       1  00:06:06.236       6
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4    295       1  00:08:54.261       8
# a5a87567-a946-4860-9f5f-75436339c59d   2433       2  00:30:36.196      75
#
#                                       second  possession  duration  type_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe       6          12    0.4963       16
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      54          19    1.3594       16
# a5a87567-a946-4860-9f5f-75436339c59d      36         138    0.4589       16
#
#                                      type_name  possession_team_id  ...  \
# id                                                                  ...
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe      Shot                1214  ...
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      Shot                1214  ...
# a5a87567-a946-4860-9f5f-75436339c59d      Shot                1214  ...
#
#                                      injury_stoppage_in_chain  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                       substitution_outcome_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                      substitution_outcome_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                       NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                       NaN
# a5a87567-a946-4860-9f5f-75436339c59d                       NaN
#
#                                       substitution_replacement_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                          NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                          NaN
# a5a87567-a946-4860-9f5f-75436339c59d                          NaN
#
#                                      substitution_replacement_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                           NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                           NaN
# a5a87567-a946-4860-9f5f-75436339c59d                           NaN
#
#                                       foul_committed_card_id  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                     NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                     NaN
# a5a87567-a946-4860-9f5f-75436339c59d                     NaN
#
#                                      foul_committed_card_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
#
#                                      50_50_outcome_id 50_50_outcome_name  \
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe              NaN                NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4              NaN                NaN
# a5a87567-a946-4860-9f5f-75436339c59d              NaN                NaN
#
#                                       match_id
# id
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe     69161
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4     69161
# a5a87567-a946-4860-9f5f-75436339c59d     69161
#
# [3 rows x 115 columns]

# %%
def DibujaCampo(length,width,linecolor):
    """Función para dibujar un campo de futbol en yards, adaptación del código de davsu428"""
    #Create figure
    fig=plt.figure()
            
    ax=fig.add_subplot(1,1,1)
           
    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,width], color=linecolor)
    plt.plot([0,length],[width,width], color=linecolor)
    plt.plot([length,length],[width,0], color=linecolor)
    plt.plot([length,0],[0,0], color=linecolor)
    plt.plot([length/2,length/2],[0,width], color=linecolor)
            
    #Left Penalty Area
    plt.plot([18 ,18],[(width/2 +18),(width/2-18)],color=linecolor)
    plt.plot([0,18],[(width/2 +18),(width/2 +18)],color=linecolor)
    plt.plot([18,0],[(width/2 -18),(width/2 -18)],color=linecolor)
            
    #Right Penalty Area
    plt.plot([(length-18),length],[(width/2 +18),(width/2 +18)],color=linecolor)
    plt.plot([(length-18), (length-18)],[(width/2 +18),(width/2-18)],color=linecolor)
    plt.plot([(length-18),length],[(width/2 -18),(width/2 -18)],color=linecolor)
            
    #Left 6-yard Box
    plt.plot([0,6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
    plt.plot([6,6],[(width/2+7.32/2+6),(width/2-7.32/2-6)],color=linecolor)
    plt.plot([6,0],[(width/2-7.32/2-6),(width/2-7.32/2-6)],color=linecolor)
            
    #Right 6-yard Box
    plt.plot([length,length-6],[(width/2+7.32/2+6),(width/2+7.32/2+6)],color=linecolor)
    plt.plot([length-6,length-6],[(width/2+7.32/2+6),width/2-7.32/2-6],color=linecolor)
    plt.plot([length-6,length],[(width/2-7.32/2-6),width/2-7.32/2-6],color=linecolor)
            
    #Prepare Circles; 10 yards distance. penalty on 12 yards
    centreCircle = plt.Circle((length/2,width/2),10,color=linecolor,fill=False)
    centreSpot = plt.Circle((length/2,width/2),0.8,color=linecolor)
    leftPenSpot = plt.Circle((12,width/2),0.8,color=linecolor)
    rightPenSpot = plt.Circle((length-12,width/2),0.8,color=linecolor)
            
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
            
    #Prepare Arcs
    leftArc = Arc((11,width/2),height=20,width=20,angle=0,theta1=312,theta2=48,color=linecolor)
    rightArc = Arc((length-11,width/2),height=20,width=20,angle=0,theta1=130,theta2=230,color=linecolor)
            
    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    #Tidy Axes
    plt.axis('off')
    
    return fig,ax

# %%
#Function to draw the pitch
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import numpy as np


#Size of the pitch in yards (!!!)
pitchLengthX=120
pitchWidthY=80
circleSize=2

# %%
shots
# Out:
#                                       index  period     timestamp  minute  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1     34       1  00:00:51.681       0
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe    199       1  00:06:06.236       6
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4    295       1  00:08:54.261       8
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539    346       1  00:12:48.506      12
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02    350       1  00:13:19.559      13
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e    459       1  00:16:46.329      16
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93    775       1  00:24:54.778      24
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b   1156       1  00:34:27.249      34
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb   1177       1  00:35:10.554      35
# 0458b135-c2f2-4ae5-813e-e182023add16   1851       2  00:07:58.324      52
# 3e767b66-7e5a-428e-a4a8-26af57a7639b   2060       2  00:14:29.178      59
# 97ea84d3-d429-48a4-9664-a2c2d489da12   2212       2  00:19:07.871      64
# 746bc451-30af-477a-b824-293543017741   2228       2  00:19:59.455      64
# a5a87567-a946-4860-9f5f-75436339c59d   2433       2  00:30:36.196      75
# b770310f-94c0-4397-ae2e-98d4ce86ace2   2505       2  00:33:35.925      78
#
#                                       second  possession  duration  type_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1      51           5  0.427600       16
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe       6          12  0.496300       16
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      54          19  1.359400       16
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539      48          24  0.374300       16
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02      19          25  0.341200       16
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e      46          32  0.163800       16
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93      54          50  0.442100       16
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b      27          72  1.028601       16
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb      10          74  1.428799       16
# 0458b135-c2f2-4ae5-813e-e182023add16      58         109  0.113900       16
# 3e767b66-7e5a-428e-a4a8-26af57a7639b      29         118  1.029600       16
# 97ea84d3-d429-48a4-9664-a2c2d489da12       7         126  1.129000       16
# 746bc451-30af-477a-b824-293543017741      59         128  1.209200       16
# a5a87567-a946-4860-9f5f-75436339c59d      36         138  0.458900       16
# b770310f-94c0-4397-ae2e-98d4ce86ace2      35         143  1.418400       16
#
#                                      type_name  possession_team_id  ...  \
# id                                                                  ...
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1      Shot                 863  ...
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe      Shot                1214  ...
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4      Shot                1214  ...
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539      Shot                1214  ...
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02      Shot                1214  ...
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e      Shot                1214  ...
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93      Shot                1214  ...
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b      Shot                1214  ...
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb      Shot                1214  ...
# 0458b135-c2f2-4ae5-813e-e182023add16      Shot                 863  ...
# 3e767b66-7e5a-428e-a4a8-26af57a7639b      Shot                1214  ...
# 97ea84d3-d429-48a4-9664-a2c2d489da12      Shot                1214  ...
# 746bc451-30af-477a-b824-293543017741      Shot                 863  ...
# a5a87567-a946-4860-9f5f-75436339c59d      Shot                1214  ...
# b770310f-94c0-4397-ae2e-98d4ce86ace2      Shot                1214  ...
#
#                                      injury_stoppage_in_chain  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                       substitution_outcome_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                      substitution_outcome_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                       NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                       NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                       NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                       NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                       NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                       NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                       NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                       NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                       NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                       NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                       NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                       NaN
# 746bc451-30af-477a-b824-293543017741                       NaN
# a5a87567-a946-4860-9f5f-75436339c59d                       NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                       NaN
#
#                                       substitution_replacement_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                          NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                          NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                          NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                          NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                          NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                          NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                          NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                          NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                          NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                          NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                          NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                          NaN
# 746bc451-30af-477a-b824-293543017741                          NaN
# a5a87567-a946-4860-9f5f-75436339c59d                          NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                          NaN
#
#                                      substitution_replacement_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                           NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                           NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                           NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                           NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                           NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                           NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                           NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                           NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                           NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                           NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                           NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                           NaN
# 746bc451-30af-477a-b824-293543017741                           NaN
# a5a87567-a946-4860-9f5f-75436339c59d                           NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                           NaN
#
#                                       foul_committed_card_id  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                     NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                     NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                     NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                     NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                     NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                     NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                     NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                     NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                     NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                     NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                     NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                     NaN
# 746bc451-30af-477a-b824-293543017741                     NaN
# a5a87567-a946-4860-9f5f-75436339c59d                     NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                     NaN
#
#                                      foul_committed_card_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1                      NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe                      NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4                      NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539                      NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02                      NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e                      NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93                      NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b                      NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb                      NaN
# 0458b135-c2f2-4ae5-813e-e182023add16                      NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b                      NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12                      NaN
# 746bc451-30af-477a-b824-293543017741                      NaN
# a5a87567-a946-4860-9f5f-75436339c59d                      NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2                      NaN
#
#                                      50_50_outcome_id 50_50_outcome_name  \
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1              NaN                NaN
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe              NaN                NaN
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4              NaN                NaN
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539              NaN                NaN
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02              NaN                NaN
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e              NaN                NaN
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93              NaN                NaN
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b              NaN                NaN
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb              NaN                NaN
# 0458b135-c2f2-4ae5-813e-e182023add16              NaN                NaN
# 3e767b66-7e5a-428e-a4a8-26af57a7639b              NaN                NaN
# 97ea84d3-d429-48a4-9664-a2c2d489da12              NaN                NaN
# 746bc451-30af-477a-b824-293543017741              NaN                NaN
# a5a87567-a946-4860-9f5f-75436339c59d              NaN                NaN
# b770310f-94c0-4397-ae2e-98d4ce86ace2              NaN                NaN
#
#                                       match_id
# id
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1     69161
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe     69161
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4     69161
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539     69161
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02     69161
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e     69161
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93     69161
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b     69161
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb     69161
# 0458b135-c2f2-4ae5-813e-e182023add16     69161
# 3e767b66-7e5a-428e-a4a8-26af57a7639b     69161
# 97ea84d3-d429-48a4-9664-a2c2d489da12     69161
# 746bc451-30af-477a-b824-293543017741     69161
# a5a87567-a946-4860-9f5f-75436339c59d     69161
# b770310f-94c0-4397-ae2e-98d4ce86ace2     69161
#
# [15 rows x 115 columns]

# %%
for i,shot in shots.iterrows():
    print(i, shot.location)
# Out:
# 5cb5dc0c-d2ff-481e-b387-ad081ba389e1 [102.8, 30.1]
# 0e5b3c7d-e58c-46b1-82c4-a4f5c43d98fe [108.1, 40.1]
# d6381cbb-e5aa-4652-80d8-3b9d57d5d4e4 [97.1, 39.7]
# 6c0c712b-ed13-45cc-a0d0-dce1f4c58539 [113.6, 30.0]
# 8e853d86-91d8-4283-b9cf-f3f0fe03fa02 [118.3, 31.2]
# 0b4785b5-1ebc-4b9c-9026-8902be38a12e [114.7, 42.1]
# 9ed0871f-5fdb-4f0d-88b9-84d026ac7b93 [108.7, 40.0]
# 41a10cad-d3af-43b6-b0ce-ff5937572b5b [94.0, 28.4]
# 76a87576-85d8-448f-9a2b-4a1d6f5f47bb [89.5, 40.9]
# 0458b135-c2f2-4ae5-813e-e182023add16 [100.3, 52.5]
# 3e767b66-7e5a-428e-a4a8-26af57a7639b [96.3, 36.2]
# 97ea84d3-d429-48a4-9664-a2c2d489da12 [98.5, 24.3]
# 746bc451-30af-477a-b824-293543017741 [102.9, 54.6]
# a5a87567-a946-4860-9f5f-75436339c59d [108.0, 40.0]
# b770310f-94c0-4397-ae2e-98d4ce86ace2 [109.9, 18.3]

# %%
(fig,ax) = DibujaCampo(pitchLengthX,pitchWidthY,'gray')

for i,shot in shots.iterrows():
    
    x=shot['location'][0]
    y=shot['location'][1]
    shotCircle=plt.Circle((x,y),2,color="red")
    ax.add_patch(shotCircle)
    
fig.set_size_inches(10, 7)
plt.show()

# %%
(fig,ax) = DibujaCampo(pitchLengthX,pitchWidthY,'gray')

for i,shot in shots.iterrows():
    
    x=shot['location'][0]
    y=shot['location'][1]
    team_name=shot['team_name']
    
    if team_name == home_team_required:
    
        shotCircle=plt.Circle((x,pitchWidthY-y),2,color="red")
        ax.add_patch(shotCircle)
        
    else:
        shotCircle=plt.Circle((pitchLengthX-x,y),2,color="blue")
        ax.add_patch(shotCircle)
        
    
fig.set_size_inches(10, 7)
plt.show()

# %%
(fig,ax) = DibujaCampo(pitchLengthX,pitchWidthY,'gray')

for i,shot in shots.iterrows():
    
    x=shot['location'][0]
    y=shot['location'][1]
    team_name=shot['team_name']
    goal=shot['shot_outcome_name']=='Goal'
    
    if team_name == home_team_required:
        if goal:
            shotCircle=plt.Circle((x,pitchWidthY-y),2,color="red")
        else:
            shotCircle=plt.Circle((x,pitchWidthY-y),circleSize,color="red")     
            shotCircle.set_alpha(.2)
        
    else:
        if goal:
            shotCircle=plt.Circle((pitchLengthX-x,y),2,color="blue")
            
            
        else:
            shotCircle=plt.Circle((pitchLengthX-x,y),2,color="blue")
            shotCircle.set_alpha(.2)
            
    ax.add_patch(shotCircle)
        
    
fig.set_size_inches(10, 7)
plt.show()

# %%
(fig,ax) = DibujaCampo(pitchLengthX,pitchWidthY,'gray')
#Plot the shots
for i,shot in shots.iterrows():
    x=shot['location'][0]
    y=shot['location'][1]
    
    goal=shot['shot_outcome_name']=='Goal'
    #print(goal)
    team_name=shot['team_name']
    
    circleSize=1.5
    
    if (team_name==home_team_required):
        if goal:
            shotCircle=plt.Circle((x,pitchWidthY-y),circleSize,color="red")
            plt.text((x+1),pitchWidthY-y+1,shot['player_name']) 
        else:
            shotCircle=plt.Circle((x,pitchWidthY-y),circleSize,color="red")     
            shotCircle.set_alpha(.2)
    elif (team_name==away_team_required):
        if goal:
            shotCircle=plt.Circle((pitchLengthX-x,y),circleSize,color="blue") 
            plt.text((pitchLengthX-x+2),y+1,shot['player_name']) 
        else:
            shotCircle=plt.Circle((pitchLengthX-x,y),circleSize,color="blue")      
            shotCircle.set_alpha(.2)
    ax.add_patch(shotCircle)
    
    
plt.text(5,75,away_team_required + ' shots') 
plt.text(80,75,home_team_required + ' shots') 
     
fig.set_size_inches(10, 7)
fig.savefig('shots.pdf', dpi=100) 
plt.show()
